# %%
# C:\Users\TUSHAR\@Projects\Credit_Card_Approval_Prediction

# %%
# new_df=pd.merge(df, df2, how='inner', on=['ID'])

# %%
import pandas as pd

# %%
ar = pd.read_csv("application_record.csv")
cr = pd.read_csv("credit_record.csv")

# %%
ar
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008805           M            Y               Y             0
# 2       5008806           M            Y               Y             0
# 3       5008808           F            N               Y             0
# 4       5008809           F            N               Y             0
# ...         ...         ...          ...             ...           ...
# 438552  6840104           M            N               Y             0
# 438553  6840222           F            N               N             0
# 438554  6841878           F            N               N             0
# 438555  6842765           F            N               Y             0
# 438556  6842885           F            N               Y             0
#
#         AMT_INCOME_TOTAL      NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
cr
# Out:
#               ID  MONTHS_BALANCE STATUS
# 0        5001711               0      X
# 1        5001711              -1      0
# 2        5001711              -2      0
# 3        5001711              -3      0
# 4        5001712               0      C
# ...          ...             ...    ...
# 1048570  5150487             -25      C
# 1048571  5150487             -26      C
# 1048572  5150487             -27      C
# 1048573  5150487             -28      C
# 1048574  5150487             -29      C
#
# [1048575 rows x 3 columns]

# %%
df = pd.merge(ar, cr, how='inner', on=['ID'])

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0       5008804           M            Y               Y             0
# 1       5008804           M            Y               Y             0
# 2       5008804           M            Y               Y             0
# 3       5008804           M            Y               Y             0
# 4       5008804           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777715 entries, 0 to 777714
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   777715 non-null  int64
#  1   CODE_GENDER          777715 non-null  object
#  2   FLAG_OWN_CAR         777715 non-null  object
#  3   FLAG_OWN_REALTY      777715 non-null  object
#  4   CNT_CHILDREN         777715 non-null  int64
#  5   AMT_INCOME_TOTAL     777715 non-null  float64
#  6   NAME_INCOME_TYPE     777715 non-null  object
#  7   NAME_EDUCATION_TYPE  777715 non-null  object
#  8   NAME_FAMILY_STATUS   777715 non-null  object
#  9   NAME_HOUSING_TYPE    777715 non-null  object
#  10  DAYS_BIRTH           777715 non-null  int64
#  11  DAYS_EMPLOYED        777715 non-null  int64
#  12  FLAG_MOBIL           777715 non-null  int64
#  13  FLAG_WORK_PHONE      777715 non-null  int64
#  14  FLAG_PHONE           777715 non-null  int64
# ...

# %%
df['OCCUPATION_TYPE'].value_counts()
# Out:
# OCCUPATION_TYPE
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: count, dtype: int64

# %%
df['OCCUPATION_TYPE'].isnull().sum()
# Out:
# 240048

# %%
df.dropna(subset=['OCCUPATION_TYPE'], inplace=True)

# %%
df
# Out:
#              ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 31      5008806           M            Y               Y             0
# 32      5008806           M            Y               Y             0
# 33      5008806           M            Y               Y             0
# 34      5008806           M            Y               Y             0
# 35      5008806           M            Y               Y             0
# ...         ...         ...          ...             ...           ...
# 777710  5150337           M            N               Y             0
# 777711  5150337           M            N               Y             0
# 777712  5150337           M            N               Y             0
# 777713  5150337           M            N               Y             0
# 777714  5150337           M            N               Y             0
#
#         AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537667 entries, 0 to 537666
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   537667 non-null  int64
#  1   CODE_GENDER          537667 non-null  object
#  2   FLAG_OWN_CAR         537667 non-null  object
#  3   FLAG_OWN_REALTY      537667 non-null  object
#  4   CNT_CHILDREN         537667 non-null  int64
#  5   AMT_INCOME_TOTAL     537667 non-null  float64
#  6   NAME_INCOME_TYPE     537667 non-null  object
#  7   NAME_EDUCATION_TYPE  537667 non-null  object
#  8   NAME_FAMILY_STATUS   537667 non-null  object
#  9   NAME_HOUSING_TYPE    537667 non-null  object
#  10  DAYS_BIRTH           537667 non-null  int64
#  11  DAYS_EMPLOYED        537667 non-null  int64
#  12  FLAG_MOBIL           537667 non-null  int64
#  13  FLAG_WORK_PHONE      537667 non-null  int64
#  14  FLAG_PHONE           537667 non-null  int64
# ...

# %% [markdown]
# # Data preprocessing

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008806           M            Y               Y             0
# 1  5008806           M            Y               Y             0
# 2  5008806           M            Y               Y             0
# 3  5008806           M            Y               Y             0
# 4  5008806           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE            NAME_EDUCATION_TYPE  \
# 0          112500.0          Working  Secondary / secondary special
# 1          112500.0          Working  Secondary / secondary special
# 2          112500.0          Working  Secondary / secondary special
# 3          112500.0          Working  Secondary / secondary special
# 4          112500.0          Working  Secondary / secondary special
#
#   NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0            Married  House / apartment      -21474          -1134
# ...

# %%
# #import seaborn as sb
# import matplotlib.pyplot as plt

# sb.heatmap(df.corr(), annot=True)

# %%
cdf = df

# %%
cdf.drop('FLAG_MOBIL',axis = 1,inplace=True)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537667 entries, 0 to 537666
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   537667 non-null  int64
#  1   CODE_GENDER          537667 non-null  object
#  2   FLAG_OWN_CAR         537667 non-null  object
#  3   FLAG_OWN_REALTY      537667 non-null  object
#  4   CNT_CHILDREN         537667 non-null  int64
#  5   AMT_INCOME_TOTAL     537667 non-null  float64
#  6   NAME_INCOME_TYPE     537667 non-null  object
#  7   NAME_EDUCATION_TYPE  537667 non-null  object
#  8   NAME_FAMILY_STATUS   537667 non-null  object
#  9   NAME_HOUSING_TYPE    537667 non-null  object
#  10  DAYS_BIRTH           537667 non-null  int64
#  11  DAYS_EMPLOYED        537667 non-null  int64
#  12  FLAG_WORK_PHONE      537667 non-null  int64
#  13  FLAG_PHONE           537667 non-null  int64
#  14  FLAG_EMAIL           537667 non-null  int64
# ...

# %%
# plt.figure(figsize=(20, 12))
# sb.heatmap(cdf.corr(), annot=True)

# %%
# Assuming 'df' is your DataFrame
object_col = cdf.select_dtypes(include='object')
object_col
# Out:
#        CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY NAME_INCOME_TYPE  \
# 0                M            Y               Y          Working
# 1                M            Y               Y          Working
# 2                M            Y               Y          Working
# 3                M            Y               Y          Working
# 4                M            Y               Y          Working
# ...            ...          ...             ...              ...
# 537662           M            N               Y          Working
# 537663           M            N               Y          Working
# 537664           M            N               Y          Working
# 537665           M            N               Y          Working
# 537666           M            N               Y          Working
#
#                   NAME_EDUCATION_TYPE    NAME_FAMILY_STATUS  \
# 0       Secondary / secondary special               Married
# 1       Secondary / secondary special               Married
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Assuming 'df' is your DataFrame and 'column_name' is the column you want to encode
le = LabelEncoder()

# Fit and transform the specified column
# df['column_name_encoded'] = le.fit_transform(df['column_name'])
# # Display the mapping of original labels to encoded labels
# print("Mapping of original labels to encoded labels:")
# label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
# print(label_mapping)

for x in object_col.columns:
    
    cdf[x] = le.fit_transform(cdf[x])
    
    print(x," Mapping of original labels to encoded labels:")
    label_mapping = dict(zip(le.classes_, le.transform(le.classes_)))
    print(label_mapping)
    print()
# Out:
# CODE_GENDER  Mapping of original labels to encoded labels:
# {'F': 0, 'M': 1}
#
# FLAG_OWN_CAR  Mapping of original labels to encoded labels:
# {'N': 0, 'Y': 1}
#
# FLAG_OWN_REALTY  Mapping of original labels to encoded labels:
# {'N': 0, 'Y': 1}
#
# NAME_INCOME_TYPE  Mapping of original labels to encoded labels:
# {'Commercial associate': 0, 'Pensioner': 1, 'State servant': 2, 'Student': 3, 'Working': 4}
#
# NAME_EDUCATION_TYPE  Mapping of original labels to encoded labels:
# {'Academic degree': 0, 'Higher education': 1, 'Incomplete higher': 2, 'Lower secondary': 3, 'Secondary / secondary special': 4}
#
# NAME_FAMILY_STATUS  Mapping of original labels to encoded labels:
# {'Civil marriage': 0, 'Married': 1, 'Separated': 2, 'Single / not married': 3, 'Widow': 4}
#
# NAME_HOUSING_TYPE  Mapping of original labels to encoded labels:
# {'Co-op apartment': 0, 'House / apartment': 1, 'Municipal apartment': 2, 'Office apartment': 3, 'Rented apartment': 4, 'With parents': 5}
#
# ...

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537667 entries, 0 to 537666
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   537667 non-null  int64
#  1   CODE_GENDER          537667 non-null  int32
#  2   FLAG_OWN_CAR         537667 non-null  int32
#  3   FLAG_OWN_REALTY      537667 non-null  int32
#  4   CNT_CHILDREN         537667 non-null  int64
#  5   AMT_INCOME_TOTAL     537667 non-null  float64
#  6   NAME_INCOME_TYPE     537667 non-null  int32
#  7   NAME_EDUCATION_TYPE  537667 non-null  int32
#  8   NAME_FAMILY_STATUS   537667 non-null  int32
#  9   NAME_HOUSING_TYPE    537667 non-null  int32
#  10  DAYS_BIRTH           537667 non-null  int64
#  11  DAYS_EMPLOYED        537667 non-null  int64
#  12  FLAG_WORK_PHONE      537667 non-null  int64
#  13  FLAG_PHONE           537667 non-null  int64
#  14  FLAG_EMAIL           537667 non-null  int64
# ...

# %%
cdf.head()
# Out:
#         ID  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008806            1             1                1             0
# 1  5008806            1             1                1             0
# 2  5008806            1             1                1             0
# 3  5008806            1             1                1             0
# 4  5008806            1             1                1             0
#
#    AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0          112500.0                 4                    4
# 1          112500.0                 4                    4
# 2          112500.0                 4                    4
# 3          112500.0                 4                    4
# 4          112500.0                 4                    4
#
#    NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                   1                  1      -21474          -1134
# ...

# %%
col = list(cdf.columns)

# %%
for i in object_col.columns:
    print(i)
    col.remove(i)
# Out:
# CODE_GENDER
# FLAG_OWN_CAR
# FLAG_OWN_REALTY
# NAME_INCOME_TYPE
# NAME_EDUCATION_TYPE
# NAME_FAMILY_STATUS
# NAME_HOUSING_TYPE
# OCCUPATION_TYPE
# STATUS

# %%
col
# Out:
# ['ID',
#  'CNT_CHILDREN',
#  'AMT_INCOME_TOTAL',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'FLAG_WORK_PHONE',
#  'FLAG_PHONE',
#  'FLAG_EMAIL',
#  'CNT_FAM_MEMBERS',
#  'MONTHS_BALANCE']

# %%
cat_fea = cdf[col]

# %%
cat_fea
# Out:
#              ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0       5008806             0          112500.0      -21474          -1134
# 1       5008806             0          112500.0      -21474          -1134
# 2       5008806             0          112500.0      -21474          -1134
# 3       5008806             0          112500.0      -21474          -1134
# 4       5008806             0          112500.0      -21474          -1134
# ...         ...           ...               ...         ...            ...
# 537662  5150337             0          112500.0       -9188          -1193
# 537663  5150337             0          112500.0       -9188          -1193
# 537664  5150337             0          112500.0       -9188          -1193
# 537665  5150337             0          112500.0       -9188          -1193
# 537666  5150337             0          112500.0       -9188          -1193
#
#         FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  \
# ...

# %%
cat_fea.describe()
# Out:
#                  ID   CNT_CHILDREN  AMT_INCOME_TOTAL     DAYS_BIRTH  \
# count  5.376670e+05  537667.000000      5.376670e+05  537667.000000
# mean   5.079231e+06       0.506697      1.971171e+05  -15010.958999
# std    4.200200e+04       0.787285      1.041390e+05    3416.418092
# min    5.008806e+06       0.000000      2.700000e+04  -24611.000000
# 25%    5.044925e+06       0.000000      1.350000e+05  -17594.000000
# 50%    5.079091e+06       0.000000      1.800000e+05  -14785.000000
# 75%    5.115755e+06       1.000000      2.295000e+05  -12239.000000
# max    5.150487e+06      19.000000      1.575000e+06   -7489.000000
#
#        DAYS_EMPLOYED  FLAG_WORK_PHONE     FLAG_PHONE     FLAG_EMAIL  \
# count  537667.000000    537667.000000  537667.000000  537667.000000
# mean    -2762.029935         0.281615       0.298893       0.100730
# std      2393.919456         0.449787       0.457773       0.300971
# min    -15713.000000         0.000000       0.000000       0.000000
# ...

# %%
cat_fea.boxplot(column = 'CNT_CHILDREN')
# Out:
# <Axes: >

# %% [markdown]
# ### Outliers function

# %%
import numpy as np

# %%
def find_outliers(column):
    Q1 = np.percentile(column, 25)
    Q3 = np.percentile(column, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = (column < lower_bound) | (column > upper_bound)
    
    print(lower_bound,upper_bound)
    return outliers

# %%
find_outliers(cdf['CNT_CHILDREN']).value_counts()
# Out:
# -1.5 2.5
# CNT_CHILDREN
# False    529637
# True       8030
# Name: count, dtype: int64

# %%
cdf.drop(cdf[cdf['CNT_CHILDREN'] > 8].index, inplace=True)
cdf.reset_index(drop=True, inplace=True)

# %%
cat_fea.boxplot(column = 'CNT_CHILDREN')

cdf['CNT_CHILDREN'].value_counts()
# Out:
# CNT_CHILDREN
# 0    343151
# 1    127695
# 2     58791
# 3      6549
# 4      1070
# 5       248
# 7        46
# Name: count, dtype: int64

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 537550 entries, 0 to 537549
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   537550 non-null  int64
#  1   CODE_GENDER          537550 non-null  int32
#  2   FLAG_OWN_CAR         537550 non-null  int32
#  3   FLAG_OWN_REALTY      537550 non-null  int32
#  4   CNT_CHILDREN         537550 non-null  int64
#  5   AMT_INCOME_TOTAL     537550 non-null  float64
#  6   NAME_INCOME_TYPE     537550 non-null  int32
#  7   NAME_EDUCATION_TYPE  537550 non-null  int32
#  8   NAME_FAMILY_STATUS   537550 non-null  int32
#  9   NAME_HOUSING_TYPE    537550 non-null  int32
#  10  DAYS_BIRTH           537550 non-null  int64
#  11  DAYS_EMPLOYED        537550 non-null  int64
#  12  FLAG_WORK_PHONE      537550 non-null  int64
#  13  FLAG_PHONE           537550 non-null  int64
#  14  FLAG_EMAIL           537550 non-null  int64
# ...

# %%
cat_fea.head()
# Out:
#         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  5008806             0          112500.0      -21474          -1134
# 1  5008806             0          112500.0      -21474          -1134
# 2  5008806             0          112500.0      -21474          -1134
# 3  5008806             0          112500.0      -21474          -1134
# 4  5008806             0          112500.0      -21474          -1134
#
#    FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  MONTHS_BALANCE
# 0                0           0           0              2.0               0
# 1                0           0           0              2.0              -1
# 2                0           0           0              2.0              -2
# 3                0           0           0              2.0              -3
# 4                0           0           0              2.0              -4

# %%
cat_fea.boxplot(column = 'AMT_INCOME_TOTAL')
# Out:
# <Axes: >

# %%
find_outliers(cdf['AMT_INCOME_TOTAL']).value_counts()
# Out:
# -6750.0 371250.0
# AMT_INCOME_TOTAL
# False    510988
# True      26562
# Name: count, dtype: int64

# %%
cdf.drop(cdf[cdf['AMT_INCOME_TOTAL'] > 400000].index,inplace = True)

# %%
cat_fea.boxplot(column = 'DAYS_EMPLOYED')
# Out:
# <Axes: >

# %%
find_outliers(cdf['DAYS_EMPLOYED']).value_counts()
# Out:
# -7578.0 2878.0
# DAYS_EMPLOYED
# False    487831
# True      28143
# Name: count, dtype: int64

# %%
cdf.drop(cdf[cdf['DAYS_EMPLOYED'] < -9875].index,inplace = True)
cdf.reset_index(drop=True, inplace=True)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505613 entries, 0 to 505612
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   505613 non-null  int64
#  1   CODE_GENDER          505613 non-null  int32
#  2   FLAG_OWN_CAR         505613 non-null  int32
#  3   FLAG_OWN_REALTY      505613 non-null  int32
#  4   CNT_CHILDREN         505613 non-null  int64
#  5   AMT_INCOME_TOTAL     505613 non-null  float64
#  6   NAME_INCOME_TYPE     505613 non-null  int32
#  7   NAME_EDUCATION_TYPE  505613 non-null  int32
#  8   NAME_FAMILY_STATUS   505613 non-null  int32
#  9   NAME_HOUSING_TYPE    505613 non-null  int32
#  10  DAYS_BIRTH           505613 non-null  int64
#  11  DAYS_EMPLOYED        505613 non-null  int64
#  12  FLAG_WORK_PHONE      505613 non-null  int64
#  13  FLAG_PHONE           505613 non-null  int64
#  14  FLAG_EMAIL           505613 non-null  int64
# ...

# %%
cat_fea.head()
# Out:
#         ID  CNT_CHILDREN  AMT_INCOME_TOTAL  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0  5008806             0          112500.0      -21474          -1134
# 1  5008806             0          112500.0      -21474          -1134
# 2  5008806             0          112500.0      -21474          -1134
# 3  5008806             0          112500.0      -21474          -1134
# 4  5008806             0          112500.0      -21474          -1134
#
#    FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  CNT_FAM_MEMBERS  MONTHS_BALANCE
# 0                0           0           0              2.0               0
# 1                0           0           0              2.0              -1
# 2                0           0           0              2.0              -2
# 3                0           0           0              2.0              -3
# 4                0           0           0              2.0              -4

# %%
# cdf.drop(cdf[cdf['CNT_FAM_MEMBERS'] > 10.0 ].index,inplace = True)
# cdf.reset_index(drop=True, inplace=True)


cdf['CNT_FAM_MEMBERS'].value_counts()
# Out:
# CNT_FAM_MEMBERS
# 2.0    261839
# 3.0    104557
# 1.0     78890
# 4.0     53201
# 5.0      5847
# 6.0       985
# 7.0       248
# 9.0        46
# Name: count, dtype: int64

# %%
cdf.boxplot(column = 'CNT_FAM_MEMBERS')

find_outliers(cdf['CNT_FAM_MEMBERS']).value_counts()
# Out:
# 0.5 4.5
# CNT_FAM_MEMBERS
# False    498487
# True       7126
# Name: count, dtype: int64

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505613 entries, 0 to 505612
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   505613 non-null  int64
#  1   CODE_GENDER          505613 non-null  int32
#  2   FLAG_OWN_CAR         505613 non-null  int32
#  3   FLAG_OWN_REALTY      505613 non-null  int32
#  4   CNT_CHILDREN         505613 non-null  int64
#  5   AMT_INCOME_TOTAL     505613 non-null  float64
#  6   NAME_INCOME_TYPE     505613 non-null  int32
#  7   NAME_EDUCATION_TYPE  505613 non-null  int32
#  8   NAME_FAMILY_STATUS   505613 non-null  int32
#  9   NAME_HOUSING_TYPE    505613 non-null  int32
#  10  DAYS_BIRTH           505613 non-null  int64
#  11  DAYS_EMPLOYED        505613 non-null  int64
#  12  FLAG_WORK_PHONE      505613 non-null  int64
#  13  FLAG_PHONE           505613 non-null  int64
#  14  FLAG_EMAIL           505613 non-null  int64
# ...

# %%
cdf.boxplot(column = 'MONTHS_BALANCE')

find_outliers(cdf['MONTHS_BALANCE']).value_counts()
# Out:
# -62.0 26.0
# MONTHS_BALANCE
# False    505613
# Name: count, dtype: int64

# %%
cdf.drop('ID',axis = 1 , inplace = True)

# %%
cdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 505613 entries, 0 to 505612
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   CODE_GENDER          505613 non-null  int32
#  1   FLAG_OWN_CAR         505613 non-null  int32
#  2   FLAG_OWN_REALTY      505613 non-null  int32
#  3   CNT_CHILDREN         505613 non-null  int64
#  4   AMT_INCOME_TOTAL     505613 non-null  float64
#  5   NAME_INCOME_TYPE     505613 non-null  int32
#  6   NAME_EDUCATION_TYPE  505613 non-null  int32
#  7   NAME_FAMILY_STATUS   505613 non-null  int32
#  8   NAME_HOUSING_TYPE    505613 non-null  int32
#  9   DAYS_BIRTH           505613 non-null  int64
#  10  DAYS_EMPLOYED        505613 non-null  int64
#  11  FLAG_WORK_PHONE      505613 non-null  int64
#  12  FLAG_PHONE           505613 non-null  int64
#  13  FLAG_EMAIL           505613 non-null  int64
#  14  OCCUPATION_TYPE      505613 non-null  int32
# ...

# %%
cdf['target']=cdf['STATUS']
cdf['target'].replace('X', 0, inplace=True)
cdf['target'].replace('C', 0, inplace=True)
cdf['target']=cdf['target'].astype(int)
cdf.loc[cdf['target']>=1,'target']=1
cdf.drop('STATUS',axis = 1,inplace = True)

# %%
cdf
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                 1             1                1             0
# 1                 1             1                1             0
# 2                 1             1                1             0
# 3                 1             1                1             0
# 4                 1             1                1             0
# ...             ...           ...              ...           ...
# 505608            1             0                1             0
# 505609            1             0                1             0
# 505610            1             0                1             0
# 505611            1             0                1             0
# 505612            1             0                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0               112500.0                 4                    4
# ...

# %% [markdown]
# ## Training and Testing

# %%
from sklearn.model_selection import KFold, cross_val_score,train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, StandardScaler, OrdinalEncoder
from sklearn.compose import ColumnTransformer

# %%
x = cdf.drop(columns=['target'])
y = cdf['target']

# %%
x
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                 1             1                1             0
# 1                 1             1                1             0
# 2                 1             1                1             0
# 3                 1             1                1             0
# 4                 1             1                1             0
# ...             ...           ...              ...           ...
# 505608            1             0                1             0
# 505609            1             0                1             0
# 505610            1             0                1             0
# 505611            1             0                1             0
# 505612            1             0                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0               112500.0                 4                    4
# ...

# %%
y
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 505608    0
# 505609    1
# 505610    1
# 505611    0
# 505612    0
# Name: target, Length: 505613, dtype: int32

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.25,stratify=y,random_state=0)

# %%
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %% [markdown]
# # Logistic Regression

# %%
lr = LogisticRegression(random_state=0)

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
lr.score(x_test,y_test)
# Out:
# 0.6277095661529698

# %%
from sklearn.metrics import confusion_matrix,classification_report


y_pred = lr.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[    0 47059]
#  [    0 79345]]
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00     47059
#            1       0.63      1.00      0.77     79345
#
#     accuracy                           0.63    126404
#    macro avg       0.31      0.50      0.39    126404
# weighted avg       0.39      0.63      0.48    126404
# C:\Users\TUSHAR\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\TUSHAR\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ### accuracy 0.63

# %% [markdown]
# # KNN

# %%
# Import necessary libraries
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report



# Standardize the feature values (optional but often recommended for k-NN)
scaler = StandardScaler()

# %%
# Create a k-NN classifier
k = 3  # Choose the number of neighbors
knn_classifier = KNeighborsClassifier(n_neighbors=k)

# Train the classifier on the training data
knn_classifier.fit(X_train_scaled, y_train)

# Make predictions on the test data
y_pred = knn_classifier.predict(X_test_scaled)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display additional classification metrics
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.72
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61     47059
#            1       0.77      0.80      0.78     79345
#
#     accuracy                           0.72    126404
#    macro avg       0.70      0.69      0.70    126404
# weighted avg       0.72      0.72      0.72    126404

# %% [markdown]
# ### Accuracy: 0.72
# Classification Report-1:
#                precision    recall  f1-score   support
#
#            0       0.63      0.59      0.61     47059
#            1       0.77      0.80      0.78     79345
#
#     accuracy                           0.72    126404
#    macro avg       0.70      0.69      0.70    126404
# weighted avg       0.72      0.72      0.72    126404

# %% [markdown]
# # decesion tree

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier 
from sklearn.metrics import accuracy_score, classification_report


dt = DecisionTreeClassifier()

# %%
dt.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt.score(x_test,y_test)
# Out:
# C:\Users\TUSHAR\anaconda3\Lib\site-packages\sklearn\base.py:432: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# 0.5915398246890922

# %% [markdown]
# ## SVM

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report
from sklearn.svm import SVC

clf = SVC(kernel='linear')

# %%
print("hello world")

# %%
clf.fit(X_train_scaled, y_train)

# %%
y_pred = clf.predict(x_test)

# Evaluate the classifier
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))a
