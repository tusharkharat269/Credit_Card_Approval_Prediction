# %%
import pandas as pd

ar = pd.read_csv("application_record.csv")
cr = pd.read_csv("credit_record.csv")

df = pd.merge(ar, cr, how='inner', on=['ID'])

# %%
df.head()
# Out:
#         ID CODE_GENDER FLAG_OWN_CAR FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0  5008804           M            Y               Y             0
# 1  5008804           M            Y               Y             0
# 2  5008804           M            Y               Y             0
# 3  5008804           M            Y               Y             0
# 4  5008804           M            Y               Y             0
#
#    AMT_INCOME_TOTAL NAME_INCOME_TYPE NAME_EDUCATION_TYPE NAME_FAMILY_STATUS  \
# 0          427500.0          Working    Higher education     Civil marriage
# 1          427500.0          Working    Higher education     Civil marriage
# 2          427500.0          Working    Higher education     Civil marriage
# 3          427500.0          Working    Higher education     Civil marriage
# 4          427500.0          Working    Higher education     Civil marriage
#
#   NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0  Rented apartment      -12005          -4542           1                1
# 1  Rented apartment      -12005          -4542           1                1
# 2  Rented apartment      -12005          -4542           1                1
# 3  Rented apartment      -12005          -4542           1                1
# 4  Rented apartment      -12005          -4542           1                1
#
#    FLAG_PHONE  FLAG_EMAIL OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  \
# 0           0           0             NaN              2.0               0
# 1           0           0             NaN              2.0              -1
# 2           0           0             NaN              2.0              -2
# 3           0           0             NaN              2.0              -3
# 4           0           0             NaN              2.0              -4
#
#   STATUS
# 0      C
# 1      C
# 2      C
# 3      C
# 4      C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777715 entries, 0 to 777714
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ID                   777715 non-null  int64
#  1   CODE_GENDER          777715 non-null  object
#  2   FLAG_OWN_CAR         777715 non-null  object
#  3   FLAG_OWN_REALTY      777715 non-null  object
#  4   CNT_CHILDREN         777715 non-null  int64
#  5   AMT_INCOME_TOTAL     777715 non-null  float64
#  6   NAME_INCOME_TYPE     777715 non-null  object
#  7   NAME_EDUCATION_TYPE  777715 non-null  object
#  8   NAME_FAMILY_STATUS   777715 non-null  object
#  9   NAME_HOUSING_TYPE    777715 non-null  object
#  10  DAYS_BIRTH           777715 non-null  int64
#  11  DAYS_EMPLOYED        777715 non-null  int64
#  12  FLAG_MOBIL           777715 non-null  int64
#  13  FLAG_WORK_PHONE      777715 non-null  int64
#  14  FLAG_PHONE           777715 non-null  int64
#  15  FLAG_EMAIL           777715 non-null  int64
#  16  OCCUPATION_TYPE      537667 non-null  object
#  17  CNT_FAM_MEMBERS      777715 non-null  float64
#  18  MONTHS_BALANCE       777715 non-null  int64
#  19  STATUS               777715 non-null  object
# dtypes: float64(2), int64(9), object(9)
# memory usage: 118.7+ MB

# %% [markdown]
# ## Duplicate records

# %%
df['ID'].unique().size
# Out:
# 36457

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ID, CODE_GENDER, FLAG_OWN_CAR, FLAG_OWN_REALTY, CNT_CHILDREN, AMT_INCOME_TOTAL, NAME_INCOME_TYPE, NAME_EDUCATION_TYPE, NAME_FAMILY_STATUS, NAME_HOUSING_TYPE, DAYS_BIRTH, DAYS_EMPLOYED, FLAG_MOBIL, FLAG_WORK_PHONE, FLAG_PHONE, FLAG_EMAIL, OCCUPATION_TYPE, CNT_FAM_MEMBERS, MONTHS_BALANCE, STATUS]
# Index: []

# %% [markdown]
# ## NUll values

# %%
df.isnull().sum()
# Out:
# ID                          0
# CODE_GENDER                 0
# FLAG_OWN_CAR                0
# FLAG_OWN_REALTY             0
# CNT_CHILDREN                0
# AMT_INCOME_TOTAL            0
# NAME_INCOME_TYPE            0
# NAME_EDUCATION_TYPE         0
# NAME_FAMILY_STATUS          0
# NAME_HOUSING_TYPE           0
# DAYS_BIRTH                  0
# DAYS_EMPLOYED               0
# FLAG_MOBIL                  0
# FLAG_WORK_PHONE             0
# FLAG_PHONE                  0
# FLAG_EMAIL                  0
# OCCUPATION_TYPE        240048
# CNT_FAM_MEMBERS             0
# MONTHS_BALANCE              0
# STATUS                      0
# dtype: int64

# %%
df['OCCUPATION_TYPE'].value_counts()
# Out:
# OCCUPATION_TYPE
# Laborers                 131572
# Core staff                77112
# Sales staff               70362
# Managers                  67738
# Drivers                   47678
# High skill tech staff     31768
# Accountants               27223
# Medicine staff            26691
# Cooking staff             13416
# Security staff            12400
# Cleaning staff            11399
# Private service staff      6714
# Low-skill Laborers         3623
# Secretaries                3149
# Waiters/barmen staff       2557
# HR staff                   1686
# IT staff                   1319
# Realty agents              1260
# Name: count, dtype: int64

# %%
# df.dropna(inplace = True)

# %% [markdown]
# ## Setting Target feature

# %%
df['STATUS'].value_counts()
# Out:
# STATUS
# C    329536
# 0    290654
# X    145950
# 1      8747
# 5      1527
# 2       801
# 3       286
# 4       214
# Name: count, dtype: int64

# %%
df['approved'] = df['STATUS']

df['approved'].replace({'X','C'} , 1, inplace=True)  # approved cards
df['approved'].replace({'1','2','3','4','5'}, -1, inplace=True) # Declined cards

df['approved']= df['approved'].astype(int)

# %%
df['approved'].value_counts()
# Out:
# approved
#  1    475486
#  0    290654
# -1     11575
# Name: count, dtype: int64

# %% [markdown]
# ## Dropping uneccesary columns

# %%
df.drop(columns = 'ID',axis = 1,inplace = True)
df.drop(columns = 'STATUS',axis = 1,inplace = True)

# %% [markdown]
# ## Label encoding categorical features

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

# %%
obj_fea = df.select_dtypes(include='object').columns

obj_fea
# Out:
# Index(['CODE_GENDER', 'FLAG_OWN_CAR', 'FLAG_OWN_REALTY', 'NAME_INCOME_TYPE',
#        'NAME_EDUCATION_TYPE', 'NAME_FAMILY_STATUS', 'NAME_HOUSING_TYPE',
#        'OCCUPATION_TYPE'],
#       dtype='object')

# %%
for each in obj_fea:
    if(df[each].dtype == 'O'):
        df[each] = le.fit_transform(df[each])
        print(le.classes_)
# Out:
# ['F' 'M']
# ['N' 'Y']
# ['N' 'Y']
# ['Commercial associate' 'Pensioner' 'State servant' 'Student' 'Working']
# ['Academic degree' 'Higher education' 'Incomplete higher'
#  'Lower secondary' 'Secondary / secondary special']
# ['Civil marriage' 'Married' 'Separated' 'Single / not married' 'Widow']
# ['Co-op apartment' 'House / apartment' 'Municipal apartment'
#  'Office apartment' 'Rented apartment' 'With parents']
# ['Accountants' 'Cleaning staff' 'Cooking staff' 'Core staff' 'Drivers'
#  'HR staff' 'High skill tech staff' 'IT staff' 'Laborers'
#  'Low-skill Laborers' 'Managers' 'Medicine staff' 'Private service staff'
#  'Realty agents' 'Sales staff' 'Secretaries' 'Security staff'
#  'Waiters/barmen staff' nan]

# %% [markdown]
# ## Dealing with null values for 'OCCUPATION_TYPE'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# plt.hist(df['OCCUPATION_TYPE'])
# sns.displot(df['OCCUPATION_TYPE'])

# %%
# df['OCCUPATION_TYPE'].value_counts()

# we don't need to replce it as we treat it as random or unknown occupation to company

# %%
df.sample(5)
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 70795             0             0                1             0
# 322410            0             0                1             0
# 449818            0             0                1             0
# 18072             1             1                0             0
# 526933            0             0                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 70795           180000.0                 4                    4
# 322410          135000.0                 1                    4
# 449818          180000.0                 1                    4
# 18072           225000.0                 4                    1
# 526933          171000.0                 4                    4
#
#         NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 70795                    3                  1      -23007         -11589
# 322410                   4                  1      -23183         365243
# 449818                   1                  1      -19945         365243
# 18072                    0                  4      -14555          -1226
# 526933                   3                  1      -23304          -3202
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 70795            1                1           1           0                1
# 322410           1                0           1           0               18
# 449818           1                0           0           0               18
# 18072            1                1           0           0               10
# 526933           1                0           1           1               18
#
#         CNT_FAM_MEMBERS  MONTHS_BALANCE  approved
# 70795               1.0              -4         1
# 322410              1.0             -16         1
# 449818              2.0             -21         1
# 18072               2.0             -46         0
# 526933              1.0             -13         1

# %%
# df.info()

# %% [markdown]
# ## checking outliers

# %%
continueous_features = ('AMT_INCOME_TOTAL','DAYS_BIRTH','DAYS_EMPLOYED','MONTHS_BALANCE')

continueous_features
# Out:
# ('AMT_INCOME_TOTAL', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'MONTHS_BALANCE')

# %%
# DAYS_BIRTH,MONTHS_BALANCE no outliers

# %%
sns.boxplot(df['AMT_INCOME_TOTAL'])
# Out:
# <Axes: >

# %%
x = df['AMT_INCOME_TOTAL']
y = df['approved']

sns.boxplot(data = df,x = "approved" , y= "AMT_INCOME_TOTAL")
# Out:
# <Axes: xlabel='approved', ylabel='AMT_INCOME_TOTAL'>

# %%
Q1 = df['AMT_INCOME_TOTAL'].quantile(0.25)
Q3 = df['AMT_INCOME_TOTAL'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

print(lower,upper)
# Out:
# -33750.0 380250.0

# %%
# df[df['AMT_INCOME_TOTAL'] < lower]
# 0

# %%
# remove the outliers

df = df[df['AMT_INCOME_TOTAL'] < upper]  

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 743728 entries, 31 to 777714
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   CODE_GENDER          743728 non-null  int32
#  1   FLAG_OWN_CAR         743728 non-null  int32
#  2   FLAG_OWN_REALTY      743728 non-null  int32
#  3   CNT_CHILDREN         743728 non-null  int64
#  4   AMT_INCOME_TOTAL     743728 non-null  float64
#  5   NAME_INCOME_TYPE     743728 non-null  int32
#  6   NAME_EDUCATION_TYPE  743728 non-null  int32
#  7   NAME_FAMILY_STATUS   743728 non-null  int32
#  8   NAME_HOUSING_TYPE    743728 non-null  int32
#  9   DAYS_BIRTH           743728 non-null  int64
#  10  DAYS_EMPLOYED        743728 non-null  int64
#  11  FLAG_MOBIL           743728 non-null  int64
#  12  FLAG_WORK_PHONE      743728 non-null  int64
#  13  FLAG_PHONE           743728 non-null  int64
#  14  FLAG_EMAIL           743728 non-null  int64
#  15  OCCUPATION_TYPE      743728 non-null  int32
#  16  CNT_FAM_MEMBERS      743728 non-null  float64
#  17  MONTHS_BALANCE       743728 non-null  int64
#  18  approved             743728 non-null  int32
# dtypes: float64(2), int32(9), int64(8)
# memory usage: 88.0 MB

# %%
plt.hist(df['DAYS_EMPLOYED'])
# Out:
# (array([617264.,      0.,      0.,      0.,      0.,      0.,      0.,
#              0.,      0., 126464.]),
#  array([-15713. ,  22382.6,  60478.2,  98573.8, 136669.4, 174765. ,
#         212860.6, 250956.2, 289051.8, 327147.4, 365243. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.violinplot(data = df,x = "approved" , y= "DAYS_EMPLOYED")

# sns.scatterplot(data = df,x = "approved" , y= "DAYS_EMPLOYED")
# Out:
# <Axes: xlabel='approved', ylabel='DAYS_EMPLOYED'>

# %%
df['DAYS_EMPLOYED'].describe()
# Out:
# count    743728.000000
# mean      59798.912667
# std      138272.542226
# min      -15713.000000
# 25%       -3263.000000
# 50%       -1662.000000
# 75%        -412.000000
# max      365243.000000
# Name: DAYS_EMPLOYED, dtype: float64

# %%
Q1 = df['DAYS_EMPLOYED'].quantile(0.25)
Q3 = df['DAYS_EMPLOYED'].quantile(0.75)
IQR = Q3 - Q1
lower = Q1 - 1.5*IQR
upper = Q3 + 1.5*IQR

print(lower,upper)
# Out:
# -7539.5 3864.5

# %%
clean_df = df[df['DAYS_EMPLOYED'] < 36500]  # consider only upto 100 years

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 617264 entries, 31 to 777714
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   CODE_GENDER          617264 non-null  int32
#  1   FLAG_OWN_CAR         617264 non-null  int32
#  2   FLAG_OWN_REALTY      617264 non-null  int32
#  3   CNT_CHILDREN         617264 non-null  int64
#  4   AMT_INCOME_TOTAL     617264 non-null  float64
#  5   NAME_INCOME_TYPE     617264 non-null  int32
#  6   NAME_EDUCATION_TYPE  617264 non-null  int32
#  7   NAME_FAMILY_STATUS   617264 non-null  int32
#  8   NAME_HOUSING_TYPE    617264 non-null  int32
#  9   DAYS_BIRTH           617264 non-null  int64
#  10  DAYS_EMPLOYED        617264 non-null  int64
#  11  FLAG_MOBIL           617264 non-null  int64
#  12  FLAG_WORK_PHONE      617264 non-null  int64
#  13  FLAG_PHONE           617264 non-null  int64
#  14  FLAG_EMAIL           617264 non-null  int64
#  15  OCCUPATION_TYPE      617264 non-null  int32
#  16  CNT_FAM_MEMBERS      617264 non-null  float64
#  17  MONTHS_BALANCE       617264 non-null  int64
#  18  approved             617264 non-null  int32
# dtypes: float64(2), int32(9), int64(8)
# memory usage: 73.0 MB

# %%
clean_df.reset_index(inplace = True)

# %%
sns.boxplot(clean_df['DAYS_EMPLOYED'])
# Out:
# <Axes: >

# %% [markdown]
# ## Feature Extraction

# %%
clean_df.loc[:, 'DAYS_EMPLOYED'] = clean_df['DAYS_EMPLOYED'].abs()
clean_df.loc[:, 'DAYS_BIRTH'] = clean_df['DAYS_BIRTH'].abs()

clean_df
# Out:
#          index  CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0           31            1             1                1             0
# 1           32            1             1                1             0
# 2           33            1             1                1             0
# 3           34            1             1                1             0
# 4           35            1             1                1             0
# ...        ...          ...           ...              ...           ...
# 617259  777710            1             0                1             0
# 617260  777711            1             0                1             0
# 617261  777712            1             0                1             0
# 617262  777713            1             0                1             0
# 617263  777714            1             0                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0               112500.0                 4                    4
# 1               112500.0                 4                    4
# 2               112500.0                 4                    4
# 3               112500.0                 4                    4
# 4               112500.0                 4                    4
# ...                  ...               ...                  ...
# 617259          112500.0                 4                    4
# 617260          112500.0                 4                    4
# 617261          112500.0                 4                    4
# 617262          112500.0                 4                    4
# 617263          112500.0                 4                    4
#
#         NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                        1                  1       21474           1134
# 1                        1                  1       21474           1134
# 2                        1                  1       21474           1134
# 3                        1                  1       21474           1134
# 4                        1                  1       21474           1134
# ...                    ...                ...         ...            ...
# 617259                   3                  4        9188           1193
# 617260                   3                  4        9188           1193
# 617261                   3                  4        9188           1193
# 617262                   3                  4        9188           1193
# 617263                   3                  4        9188           1193
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 0                1                0           0           0               16
# 1                1                0           0           0               16
# 2                1                0           0           0               16
# 3                1                0           0           0               16
# 4                1                0           0           0               16
# ...            ...              ...         ...         ...              ...
# 617259           1                0           0           0                8
# 617260           1                0           0           0                8
# 617261           1                0           0           0                8
# 617262           1                0           0           0                8
# 617263           1                0           0           0                8
#
#         CNT_FAM_MEMBERS  MONTHS_BALANCE  approved
# 0                   2.0               0         1
# 1                   2.0              -1         1
# 2                   2.0              -2         1
# 3                   2.0              -3         1
# 4                   2.0              -4         1
# ...                 ...             ...       ...
# 617259              1.0              -9         0
# 617260              1.0             -10        -1
# 617261              1.0             -11        -1
# 617262              1.0             -12         0
# 617263              1.0             -13         0
#
# [617264 rows x 20 columns]

# %%
clean_df.drop(columns = 'index',inplace = True)
# Out:
# C:\Users\TUSHAR\AppData\Local\Temp\ipykernel_15072\2884017188.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_df.drop(columns = 'index',inplace = True)

# %%
# clean_df['CNT_FAM_MEMBERS'].value_counts()

# %%
# clean_df.loc[:, 'CNT_FAM_MEMBERS'] = clean_df['CNT_FAM_MEMBERS'].astype(int)

# %%
# clean_df['CNT_FAM_MEMBERS'].value_counts()

# %%
# clean_df[clean_df['DAYS_BIRTH'] > clean_df['DAYS_EMPLOYED']]
# 0

# %%
# plt.hist(clean_df['DAYS_EMPLOYED'])
# plt.hist(clean_df['AMT_INCOME_TOTAL'])

# %%
clean_df.head()
# Out:
#    CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0            1             1                1             0          112500.0
# 1            1             1                1             0          112500.0
# 2            1             1                1             0          112500.0
# 3            1             1                1             0          112500.0
# 4            1             1                1             0          112500.0
#
#    NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  \
# 0                 4                    4                   1
# 1                 4                    4                   1
# 2                 4                    4                   1
# 3                 4                    4                   1
# 4                 4                    4                   1
#
#    NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  \
# 0                  1       21474           1134           1                0
# 1                  1       21474           1134           1                0
# 2                  1       21474           1134           1                0
# 3                  1       21474           1134           1                0
# 4                  1       21474           1134           1                0
#
#    FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  \
# 0           0           0               16              2.0               0
# 1           0           0               16              2.0              -1
# 2           0           0               16              2.0              -2
# 3           0           0               16              2.0              -3
# 4           0           0               16              2.0              -4
#
#    approved
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %% [markdown]
# ##  Feature Normalization

# %%
conti_fea = ('AMT_INCOME_TOTAL','DAYS_BIRTH','DAYS_EMPLOYED')

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# %%
for i in conti_fea:
    clean_df.loc[:, i] = scaler.fit_transform(clean_df[[i]])

# %%
clean_df
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# 0                 1             1                1             0
# 1                 1             1                1             0
# 2                 1             1                1             0
# 3                 1             1                1             0
# 4                 1             1                1             0
# ...             ...           ...              ...           ...
# 617259            1             0                1             0
# 617260            1             0                1             0
# 617261            1             0                1             0
# 617262            1             0                1             0
# 617263            1             0                1             0
#
#         AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# 0              -0.954387                 4                    4
# 1              -0.954387                 4                    4
# 2              -0.954387                 4                    4
# 3              -0.954387                 4                    4
# 4              -0.954387                 4                    4
# ...                  ...               ...                  ...
# 617259         -0.954387                 4                    4
# 617260         -0.954387                 4                    4
# 617261         -0.954387                 4                    4
# 617262         -0.954387                 4                    4
# 617263         -0.954387                 4                    4
#
#         NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  DAYS_EMPLOYED  \
# 0                        1                  1    1.886322      -0.675638
# 1                        1                  1    1.886322      -0.675638
# 2                        1                  1    1.886322      -0.675638
# 3                        1                  1    1.886322      -0.675638
# 4                        1                  1    1.886322      -0.675638
# ...                    ...                ...         ...            ...
# 617259                   3                  4   -1.675646      -0.651419
# 617260                   3                  4   -1.675646      -0.651419
# 617261                   3                  4   -1.675646      -0.651419
# 617262                   3                  4   -1.675646      -0.651419
# 617263                   3                  4   -1.675646      -0.651419
#
#         FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  OCCUPATION_TYPE  \
# 0                1                0           0           0               16
# 1                1                0           0           0               16
# 2                1                0           0           0               16
# 3                1                0           0           0               16
# 4                1                0           0           0               16
# ...            ...              ...         ...         ...              ...
# 617259           1                0           0           0                8
# 617260           1                0           0           0                8
# 617261           1                0           0           0                8
# 617262           1                0           0           0                8
# 617263           1                0           0           0                8
#
#         CNT_FAM_MEMBERS  MONTHS_BALANCE  approved
# 0                   2.0               0         1
# 1                   2.0              -1         1
# 2                   2.0              -2         1
# 3                   2.0              -3         1
# 4                   2.0              -4         1
# ...                 ...             ...       ...
# 617259              1.0              -9         0
# 617260              1.0             -10        -1
# 617261              1.0             -11        -1
# 617262              1.0             -12         0
# 617263              1.0             -13         0
#
# [617264 rows x 19 columns]

# %% [markdown]
# ## Feature Selection

# %%
clean_df.corr()
# Out:
#                      CODE_GENDER  FLAG_OWN_CAR  FLAG_OWN_REALTY  CNT_CHILDREN  \
# CODE_GENDER             1.000000      0.347930        -0.045249      0.060338
# FLAG_OWN_CAR            0.347930      1.000000         0.001871      0.073274
# FLAG_OWN_REALTY        -0.045249      0.001871         1.000000      0.015766
# CNT_CHILDREN            0.060338      0.073274         0.015766      1.000000
# AMT_INCOME_TOTAL        0.215882      0.209994         0.025764     -0.013571
# NAME_INCOME_TYPE        0.057661     -0.004909        -0.007822      0.038041
# NAME_EDUCATION_TYPE     0.051885     -0.075505         0.001669     -0.027789
# NAME_FAMILY_STATUS     -0.067842     -0.098804         0.021421     -0.144329
# NAME_HOUSING_TYPE       0.043941      0.004327        -0.177194      0.010682
# DAYS_BIRTH             -0.127444     -0.092317         0.091989     -0.280424
# DAYS_EMPLOYED          -0.128730     -0.068953         0.007673     -0.072969
# FLAG_MOBIL                   NaN           NaN              NaN           NaN
# FLAG_WORK_PHONE         0.018348     -0.021701        -0.210952     -0.012529
# FLAG_PHONE             -0.034989     -0.027158        -0.060626     -0.022239
# FLAG_EMAIL             -0.031211      0.009912         0.069646     -0.003247
# OCCUPATION_TYPE        -0.045736     -0.036629        -0.000547     -0.014004
# CNT_FAM_MEMBERS         0.087514      0.119360         0.010908      0.904174
# MONTHS_BALANCE          0.013025     -0.005117        -0.008143     -0.001427
# approved                0.002189      0.007364        -0.000260     -0.002042
#
#                      AMT_INCOME_TOTAL  NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  \
# CODE_GENDER                  0.215882          0.057661             0.051885
# FLAG_OWN_CAR                 0.209994         -0.004909            -0.075505
# FLAG_OWN_REALTY              0.025764         -0.007822             0.001669
# CNT_CHILDREN                -0.013571          0.038041            -0.027789
# AMT_INCOME_TOTAL             1.000000         -0.139734            -0.198199
# NAME_INCOME_TYPE            -0.139734          1.000000             0.115580
# NAME_EDUCATION_TYPE         -0.198199          0.115580             1.000000
# NAME_FAMILY_STATUS           0.039078         -0.005469            -0.026294
# NAME_HOUSING_TYPE           -0.027545         -0.001397            -0.021931
# DAYS_BIRTH                   0.013032          0.032729             0.150792
# DAYS_EMPLOYED                0.017320          0.042870             0.044017
# FLAG_MOBIL                        NaN               NaN                  NaN
# FLAG_WORK_PHONE             -0.096325          0.067589             0.018710
# FLAG_PHONE                  -0.001285          0.011257            -0.033799
# FLAG_EMAIL                   0.063838         -0.047913            -0.098388
# OCCUPATION_TYPE             -0.027434         -0.016804             0.018691
# CNT_FAM_MEMBERS             -0.026236          0.039530            -0.014099
# MONTHS_BALANCE              -0.006735         -0.004193             0.001616
# approved                    -0.006766          0.009954            -0.015316
#
#                      NAME_FAMILY_STATUS  NAME_HOUSING_TYPE  DAYS_BIRTH  \
# CODE_GENDER                   -0.067842           0.043941   -0.127444
# FLAG_OWN_CAR                  -0.098804           0.004327   -0.092317
# FLAG_OWN_REALTY                0.021421          -0.177194    0.091989
# CNT_CHILDREN                  -0.144329           0.010682   -0.280424
# AMT_INCOME_TOTAL               0.039078          -0.027545    0.013032
# NAME_INCOME_TYPE              -0.005469          -0.001397    0.032729
# NAME_EDUCATION_TYPE           -0.026294          -0.021931    0.150792
# NAME_FAMILY_STATUS             1.000000           0.023646    0.044356
# NAME_HOUSING_TYPE              0.023646           1.000000   -0.173442
# DAYS_BIRTH                     0.044356          -0.173442    1.000000
# DAYS_EMPLOYED                  0.012504          -0.063677    0.335470
# FLAG_MOBIL                          NaN                NaN         NaN
# FLAG_WORK_PHONE               -0.041039           0.004634   -0.043826
# FLAG_PHONE                    -0.016635          -0.007066    0.043017
# FLAG_EMAIL                     0.002511          -0.003146   -0.069337
# OCCUPATION_TYPE               -0.008973          -0.013684   -0.018385
# CNT_FAM_MEMBERS               -0.504625          -0.010673   -0.243338
# MONTHS_BALANCE                 0.018645           0.017442   -0.045905
# approved                      -0.013172           0.000255   -0.007658
#
#                      DAYS_EMPLOYED  FLAG_MOBIL  FLAG_WORK_PHONE  FLAG_PHONE  \
# CODE_GENDER              -0.128730         NaN         0.018348   -0.034989
# FLAG_OWN_CAR             -0.068953         NaN        -0.021701   -0.027158
# FLAG_OWN_REALTY           0.007673         NaN        -0.210952   -0.060626
# CNT_CHILDREN             -0.072969         NaN        -0.012529   -0.022239
# AMT_INCOME_TOTAL          0.017320         NaN        -0.096325   -0.001285
# NAME_INCOME_TYPE          0.042870         NaN         0.067589    0.011257
# NAME_EDUCATION_TYPE       0.044017         NaN         0.018710   -0.033799
# NAME_FAMILY_STATUS        0.012504         NaN        -0.041039   -0.016635
# NAME_HOUSING_TYPE        -0.063677         NaN         0.004634   -0.007066
# DAYS_BIRTH                0.335470         NaN        -0.043826    0.043017
# DAYS_EMPLOYED             1.000000         NaN        -0.008056    0.038529
# FLAG_MOBIL                     NaN         NaN              NaN         NaN
# FLAG_WORK_PHONE          -0.008056         NaN         1.000000    0.347066
# FLAG_PHONE                0.038529         NaN         0.347066    1.000000
# FLAG_EMAIL               -0.048000         NaN        -0.067167    0.004893
# OCCUPATION_TYPE          -0.009596         NaN        -0.030810   -0.005550
# CNT_FAM_MEMBERS          -0.063514         NaN         0.008788   -0.008444
# MONTHS_BALANCE           -0.042268         NaN         0.001030   -0.004865
# approved                  0.010664         NaN         0.007583   -0.004676
#
#                      FLAG_EMAIL  OCCUPATION_TYPE  CNT_FAM_MEMBERS  \
# CODE_GENDER           -0.031211        -0.045736         0.087514
# FLAG_OWN_CAR           0.009912        -0.036629         0.119360
# FLAG_OWN_REALTY        0.069646        -0.000547         0.010908
# CNT_CHILDREN          -0.003247        -0.014004         0.904174
# AMT_INCOME_TOTAL       0.063838        -0.027434        -0.026236
# NAME_INCOME_TYPE      -0.047913        -0.016804         0.039530
# NAME_EDUCATION_TYPE   -0.098388         0.018691        -0.014099
# NAME_FAMILY_STATUS     0.002511        -0.008973        -0.504625
# NAME_HOUSING_TYPE     -0.003146        -0.013684        -0.010673
# DAYS_BIRTH            -0.069337        -0.018385        -0.243338
# DAYS_EMPLOYED         -0.048000        -0.009596        -0.063514
# FLAG_MOBIL                  NaN              NaN              NaN
# FLAG_WORK_PHONE       -0.067167        -0.030810         0.008788
# FLAG_PHONE             0.004893        -0.005550        -0.008444
# FLAG_EMAIL             1.000000        -0.000023        -0.006718
# OCCUPATION_TYPE       -0.000023         1.000000        -0.009025
# CNT_FAM_MEMBERS       -0.006718        -0.009025         1.000000
# MONTHS_BALANCE         0.004887        -0.000568        -0.010410
# approved              -0.006642        -0.005145         0.001132
#
#                      MONTHS_BALANCE  approved
# CODE_GENDER                0.013025  0.002189
# FLAG_OWN_CAR              -0.005117  0.007364
# FLAG_OWN_REALTY           -0.008143 -0.000260
# CNT_CHILDREN              -0.001427 -0.002042
# AMT_INCOME_TOTAL          -0.006735 -0.006766
# NAME_INCOME_TYPE          -0.004193  0.009954
# NAME_EDUCATION_TYPE        0.001616 -0.015316
# NAME_FAMILY_STATUS         0.018645 -0.013172
# NAME_HOUSING_TYPE          0.017442  0.000255
# DAYS_BIRTH                -0.045905 -0.007658
# DAYS_EMPLOYED             -0.042268  0.010664
# FLAG_MOBIL                      NaN       NaN
# FLAG_WORK_PHONE            0.001030  0.007583
# FLAG_PHONE                -0.004865 -0.004676
# FLAG_EMAIL                 0.004887 -0.006642
# OCCUPATION_TYPE           -0.000568 -0.005145
# CNT_FAM_MEMBERS           -0.010410  0.001132
# MONTHS_BALANCE             1.000000  0.145489
# approved                   0.145489  1.000000

# %%
# FLAG_OWN_REALTY,NAME_HOUSING_TYPE,FLAG_MOBIL

# %%
clean_df.drop(columns = {'FLAG_OWN_REALTY','NAME_HOUSING_TYPE','FLAG_MOBIL'},axis = 1,inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[501], line 1
# ----> 1 clean_df.drop(columns = {'FLAG_OWN_REALTY','NAME_HOUSING_TYPE','FLAG_MOBIL'},axis = 1,inplace = True)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['NAME_HOUSING_TYPE', 'FLAG_OWN_REALTY', 'FLAG_MOBIL'] not found in axis"

# %%
clean_df.sample(5)
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 124036            0             1             0          2.504571
# 180961            0             0             0         -0.325486
# 449519            0             1             0          0.932317
# 383547            0             1             0         -0.639937
# 452750            1             1             0         -0.011035
#
#         NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  DAYS_BIRTH  \
# 124036                 0                    1                   1   -1.476180
# 180961                 4                    1                   2    0.768387
# 449519                 4                    4                   3   -0.927070
# 383547                 4                    1                   1    0.145057
# 452750                 2                    4                   0   -0.210966
#
#         DAYS_EMPLOYED  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 124036      -0.293887                1           1           0
# 180961       0.397368                0           0           0
# 449519      -1.024139                0           0           0
# 383547       0.843154                0           0           1
# 452750       0.312398                0           0           0
#
#         OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  approved
# 124036               10              2.0             -26         1
# 180961               18              1.0             -40         1
# 449519               14              1.0             -11         1
# 383547               18              2.0             -56         1
# 452750                3              2.0             -31         1

# %%
clean_df['approved'].value_counts()
# Out:
# approved
#  1    377602
#  0    230316
# -1      9346
# Name: count, dtype: int64

# %%
final_df = clean_df[clean_df['approved'] != -1]

final_df
# Out:
#         CODE_GENDER  FLAG_OWN_CAR  CNT_CHILDREN  AMT_INCOME_TOTAL  \
# 0                 1             1             0         -0.954387
# 1                 1             1             0         -0.954387
# 2                 1             1             0         -0.954387
# 3                 1             1             0         -0.954387
# 4                 1             1             0         -0.954387
# ...             ...           ...           ...               ...
# 617257            1             0             0         -0.954387
# 617258            1             0             0         -0.954387
# 617259            1             0             0         -0.954387
# 617262            1             0             0         -0.954387
# 617263            1             0             0         -0.954387
#
#         NAME_INCOME_TYPE  NAME_EDUCATION_TYPE  NAME_FAMILY_STATUS  DAYS_BIRTH  \
# 0                      4                    4                   1    1.886322
# 1                      4                    4                   1    1.886322
# 2                      4                    4                   1    1.886322
# 3                      4                    4                   1    1.886322
# 4                      4                    4                   1    1.886322
# ...                  ...                  ...                 ...         ...
# 617257                 4                    4                   3   -1.675646
# 617258                 4                    4                   3   -1.675646
# 617259                 4                    4                   3   -1.675646
# 617262                 4                    4                   3   -1.675646
# 617263                 4                    4                   3   -1.675646
#
#         DAYS_EMPLOYED  FLAG_WORK_PHONE  FLAG_PHONE  FLAG_EMAIL  \
# 0           -0.675638                0           0           0
# 1           -0.675638                0           0           0
# 2           -0.675638                0           0           0
# 3           -0.675638                0           0           0
# 4           -0.675638                0           0           0
# ...               ...              ...         ...         ...
# 617257      -0.651419                0           0           0
# 617258      -0.651419                0           0           0
# 617259      -0.651419                0           0           0
# 617262      -0.651419                0           0           0
# 617263      -0.651419                0           0           0
#
#         OCCUPATION_TYPE  CNT_FAM_MEMBERS  MONTHS_BALANCE  approved
# 0                    16              2.0               0         1
# 1                    16              2.0              -1         1
# 2                    16              2.0              -2         1
# 3                    16              2.0              -3         1
# 4                    16              2.0              -4         1
# ...                 ...              ...             ...       ...
# 617257                8              1.0              -7         0
# 617258                8              1.0              -8         0
# 617259                8              1.0              -9         0
# 617262                8              1.0             -12         0
# 617263                8              1.0             -13         0
#
# [607918 rows x 16 columns]

# %%
final_df['approved'].value_counts()
# Out:
# approved
# 1    377602
# 0    230316
# Name: count, dtype: int64

# %% [markdown]
# ## Splitting data into Train and Test

# %%
x = final_df.drop(columns = 'approved',axis = 1)
y = final_df['approved']

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x,y,shuffle= True, test_size = 0.15)

# %% [markdown]
# ## Data balancing

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(random_state=42, sampling_strategy = 'majority')

# %%
x_train, y_train = rus.fit_resample(x_train, y_train)

# %%
# x_train

# %%
y_train.value_counts()
# Out:
# approved
# 0    195587
# 1    195587
# Name: count, dtype: int64

# %%
y_test
# Out:
# 487083    1
# 231286    1
# 601453    1
# 23236     1
# 575543    1
#          ..
# 394165    1
# 411142    1
# 286210    1
# 580703    1
# 232551    1
# Name: approved, Length: 91188, dtype: int32

# %% [markdown]
# ## Model Selection

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# C:\Users\TUSHAR\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
from sklearn.metrics import confusion_matrix,classification_report


y_pred = lr.predict(x_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[17789 16940]
#  [22375 34084]]
#               precision    recall  f1-score   support
#
#            0       0.44      0.51      0.48     34729
#            1       0.67      0.60      0.63     56459
#
#     accuracy                           0.57     91188
#    macro avg       0.56      0.56      0.55     91188
# weighted avg       0.58      0.57      0.57     91188

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report



# Standardize the feature values (optional but often recommended for k-NN)
scaler = StandardScaler()

# %%
# Create a k-NN classifier
  # Choose the number of neighbors
knn_classifier = KNeighborsClassifier(n_neighbors=7)

# Train the classifier on the training data
knn_classifier.fit(x_train, y_train)

# Make predictions on the test data
y_pred = knn_classifier.predict(x_test)

# %%
# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy:.2f}")

# Display additional classification metrics
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.63
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.51      0.75      0.61     34729
#            1       0.78      0.55      0.65     56459
#
#     accuracy                           0.63     91188
#    macro avg       0.65      0.65      0.63     91188
# weighted avg       0.68      0.63      0.63     91188
